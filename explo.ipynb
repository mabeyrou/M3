# %%
import pandas as pd
from os.path import join

# %%
data_path = join('data', 'raw_data.csv')
df = pd.read_csv(data_path)

# %%
df.head()
# Out:
#       nom    prenom  age  taille  poids sexe sport_licence niveau_etude  \
# 0  Foster    Steven   19   175.0   62.5    H           non          bac
# 1   Tapia      Todd   31   190.0   63.5    H           oui        bac+2
# 2   Hardy  Michelle   68   174.6   66.5    H           oui     doctorat
# 3  Newton   Kenneth   50   187.1  106.8    H           oui       master
# 4  Davila  Kathleen   42   169.7   63.4    H           oui       master
#
#                        region smoker nationalité_francaise  \
# 0               Île-de-France    oui                   oui
# 1                       Corse    non                   oui
# 2        Auvergne-Rhône-Alpes    oui                   oui
# 3                   Occitanie    non                   non
# 4  Provence-Alpes-Côte d’Azur    non                   non
#
#    revenu_estime_mois situation_familiale  historique_credits  \
# 0                4958                veuf                 NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   nom                    10000 non-null  object
#  1   prenom                 10000 non-null  object
#  2   age                    10000 non-null  int64
#  3   taille                 10000 non-null  float64
#  4   poids                  10000 non-null  float64
#  5   sexe                   10000 non-null  object
#  6   sport_licence          10000 non-null  object
#  7   niveau_etude           10000 non-null  object
#  8   region                 10000 non-null  object
#  9   smoker                 10000 non-null  object
#  10  nationalité_francaise  10000 non-null  object
#  11  revenu_estime_mois     10000 non-null  int64
#  12  situation_familiale    7545 non-null   object
#  13  historique_credits     4692 non-null   float64
# ...
